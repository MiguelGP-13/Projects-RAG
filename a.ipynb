# %%
import redis

REDIS_DB = redis.Redis(
    host='rag-redis.onrender.com',
    port=6379,
    password='RAG_REDIS_2025',
    ssl=True  # Redis doesn’t use SSL unless you’ve configured it
)

print(REDIS_DB.ping())  # Should return True
